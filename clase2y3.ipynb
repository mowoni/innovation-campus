# %% [markdown]
# <a href="https://colab.research.google.com/github/mowoni/innovation-campus/blob/creada-por-copilot/clase2y3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1
# Out:
# 2

# %% [markdown]
# 1+1

# %%
![imagen de paajaro azul] (https://tse1.mm.bing.net/th/id/OIP.9uQeXJPOGm7x6d4fFhnXxAHaD4?r=0&rs=1&pid=ImgDetMain&o=7&rm=3)
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `[imagen de paajaro azul] (https://tse1.mm.bing.net/th/id/OIP.9uQeXJPOGm7x6d4fFhnXxAHaD4?r=0&rs=1&pid=ImgDetMain&o=7&rm=3)'

# %% [markdown]
# https://developer.mozilla.org/es/docs/MDN/Writing_guidelines/Howto/Images_media
# https://www.markdownguide.org/
# https://github.com/mowoni?tab=packages
#
# ![imagen de pajarito azul](https://tse2.mm.bing.net/th/id/OIP.iZATgvFVmmdlky5PLVi7PwHaE8?r=0&rs=1&pid=ImgDetMain&o=7&rm=3)
#
# holi soy un texto
# #hola
# ##hola
# ###hola
#  *etoy* **probando** formatos
# ***aqui***
#
#  otro
#
# > una cita
#
#
# > # una cita grande si funciona
# y puedo seguir
#
# ![imagen de pajarito azul](https://tse1.mm.bing.net/th/id/OIP.9uQeXJPOGm7x6d4fFhnXxAHaD4?r=0&rs=1&pid=ImgDetMain&o=7&rm=3)
#
#
#
#
#
# ```
# ![imagen de paajaro azul] (https://tse1.mm.bing.net/th/id/OIP.9uQeXJPOGm7x6d4fFhnXxAHaD4?r=0&rs=1&pid=ImgDetMain&o=7&rm=3)
# ```

# %% [markdown]
# <div class="notecard warning">
#   <p><strong>Advertencia:</strong> Así es como se escribe una advertencia.</p>
#   <p>Puede tener varios párrafos.</p>
# </div>

# %%
<div class="notecard warning">
  <p><strong>Advertencia:</strong> Así es como se escribe una advertencia.</p>
  <p>Puede tener varios párrafos.</p>
</div>
# Out:
#   File "/tmp/ipython-input-104254380.py", line 1
#     <div class="notecard warning">
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![imagen de paajaro azul] (https://tse1.mm.bing.net/th/id/OIP.9uQeXJPOGm7x6d4fFhnXxAHaD4?r=0&rs=1&pid=ImgDetMain&o=7&rm=3)

# %%
![imagen de pajarito azul](https://tse1.mm.bing.net/th/id/OIP.9uQeXJPOGm7x6d4fFhnXxAHaD4?r=0&rs=1&pid=ImgDetMain&o=7&rm=3)
# Out:
# /bin/bash: -c: line 1: syntax error near unexpected token `('
# /bin/bash: -c: line 1: `[imagen de pajarito azul](https://tse1.mm.bing.net/th/id/OIP.9uQeXJPOGm7x6d4fFhnXxAHaD4?r=0&rs=1&pid=ImgDetMain&o=7&rm=3)'
